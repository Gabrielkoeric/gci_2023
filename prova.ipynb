# %%
import pandas as pd

# %%
import pandas as pd

base = pd.read_excel('BRCidades.xlsx')

base.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0              municipio   codigo  area_territorial  \
# 0             0           0             Açailândia  2100055          5808.304
# 1             1           1           Afonso Cunha  2100105           371.338
# 2             2           2  Água Doce do Maranhão  2100154           443.267
# 3             3           3              Alcântara  2100204          1168.246
# 4             4           4          Aldeias Altas  2100303          1942.121
#
#    populacao_estimada  densidade_demografica  escolarizacao   idhm  \
# 0              113121                  17.92           97.7  0.672
# 1                6578                  15.90           96.6  0.529
# 2               12652                  26.13           98.3  0.500
# 3               22112                  14.70           96.8  0.573
# 4               26757                  12.33           94.9  0.513
#
#    mortalidade_infantil  ...  GVA_agropecuaria GVA_industria  GVA_Servicos  \
# ...

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5536 entries, 0 to 5535
# Data columns (total 39 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0.1             5536 non-null   int64
#  1   Unnamed: 0               5536 non-null   int64
#  2   municipio                5536 non-null   object
#  3   codigo                   5536 non-null   int64
#  4   area_territorial         5536 non-null   float64
#  5   populacao_estimada       5536 non-null   int64
#  6   densidade_demografica    5531 non-null   float64
#  7   escolarizacao            5531 non-null   float64
#  8   idhm                     5531 non-null   float64
#  9   mortalidade_infantil     1574 non-null   float64
#  10  pib_per_capita           5536 non-null   float64
#  11  uf                       5536 non-null   object
#  12  receitas_realizadas      5514 non-null   float64
#  13  despesas_empenhadas      5514 non-null   float64
# ...

# %%
colunas1 = base[['area_territorial','estado', 'populacao_estimada', 'densidade_demografica',
'escolarizacao', 'idhm', 'mortalidade_infantil', 'pib_per_capita', 'receitas_realizadas', 'despesas_empenhadas',
'saldo_receitas_despesas', 'unidades','unidades_urbanas', 'unidades_rurais', 'area_plantada', 'producao_graos',
'IDHM_Renda', 'IDHM_Longevidade', 'IDHM_Educacao', 'GVA_agropecuaria', 'GVA_industria', 'GVA_Servicos',
'GVA_publico', 'GDP', 'GDP_populacao', 'GDP_per_capita', 'estabelecimentos', 'carros', 'motos' ]]
colunas1
# Out:
#       area_territorial estado  populacao_estimada  densidade_demografica  \
# 0             5808.304     MA              113121                  17.92
# 1              371.338     MA                6578                  15.90
# 2              443.267     MA               12652                  26.13
# 3             1168.246     MA               22112                  14.70
# 4             1942.121     MA               26757                  12.33
# ...                ...    ...                 ...                    ...
# 5531          8025.045     RR               18913                   1.30
# 5532         33579.739     RR               30782                   0.72
# 5533          4284.505     RR                8348                   1.58
# 5534          1526.898     RR                8110                   4.42
# 5535          8113.598     RR               10789                   1.04
#
#       escolarizacao   idhm  mortalidade_infantil  pib_per_capita  \
# ...

# %%
colunas2 = base[['area_territorial','estado', 'populacao_estimada', 'densidade_demografica',
'escolarizacao', 'idhm', 'mortalidade_infantil', 'pib_per_capita', 'receitas_realizadas', 'despesas_empenhadas',
'saldo_receitas_despesas', 'unidades','unidades_urbanas', 'unidades_rurais', 'area_plantada']]
colunas2
# Out:
#       area_territorial estado  populacao_estimada  densidade_demografica  \
# 0             5808.304     MA              113121                  17.92
# 1              371.338     MA                6578                  15.90
# 2              443.267     MA               12652                  26.13
# 3             1168.246     MA               22112                  14.70
# 4             1942.121     MA               26757                  12.33
# ...                ...    ...                 ...                    ...
# 5531          8025.045     RR               18913                   1.30
# 5532         33579.739     RR               30782                   0.72
# 5533          4284.505     RR                8348                   1.58
# 5534          1526.898     RR                8110                   4.42
# 5535          8113.598     RR               10789                   1.04
#
#       escolarizacao   idhm  mortalidade_infantil  pib_per_capita  \
# ...

# %%
colunas3 = base[['producao_graos', 'IDHM_Renda', 'IDHM_Longevidade', 'IDHM_Educacao', 'GVA_agropecuaria', 'GVA_industria', 'GVA_Servicos',
'GVA_publico', 'GDP', 'GDP_populacao', 'GDP_per_capita', 'estabelecimentos', 'carros', 'motos' ]]
colunas2
# Out:
#       producao_graos  IDHM_Renda  IDHM_Longevidade  IDHM_Educacao  \
# 0              89420       0.643             0.785          0.602
# 1              17098       0.471             0.725          0.434
# 2               4050       0.494             0.697          0.363
# 3               3831       0.525             0.753          0.475
# 4              78843       0.500             0.720          0.374
# ...              ...         ...               ...            ...
# 5531            9330       0.624             0.788          0.558
# 5532           22284       0.574             0.798          0.519
# 5533           17342       0.614             0.780          0.587
# 5534            8462       0.605             0.788          0.574
# 5535           30709       0.439             0.766          0.276
#
#       GVA_agropecuaria  GVA_industria  GVA_Servicos  GVA_publico         GDP  \
# 0            159853.84      488799.22        779.84    364811.85  1999546.31
# ...

# %%
colunas4 = base[['IDHM_Renda']]
colunas4
# Out:
#       IDHM_Renda
# 0          0.643
# 1          0.471
# 2          0.494
# 3          0.525
# 4          0.500
# ...          ...
# 5531       0.624
# 5532       0.574
# 5533       0.614
# 5534       0.605
# 5535       0.439
#
# [5536 rows x 1 columns]

# %%
am = colunas4.loc[base['estado'] == 'AM']
am
# Out:
#       IDHM_Renda
# 3198       0.499
# 3199       0.499
# 3200       0.537
# 3201       0.540
# 3202       0.621
# ...          ...
# 3255       0.637
# 3256       0.508
# 3257       0.535
# 3258       0.551
# 3259       0.538
#
# [62 rows x 1 columns]

# %%
round(am['populacao_estimada'].describe(),2)
# Out:
# count         62.00
# mean       67866.35
# std       278716.49
# min         2251.00
# 25%        17007.50
# 50%        25955.50
# 75%        40235.75
# max      2219580.00
# Name: populacao_estimada, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

am.boxplot(by=None, figsize=(7,8))
plt.title('Boxplot')
plt.ylabel('Valores')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

am.boxplot(by=None, figsize=(70,20))
plt.title('Boxplot')
plt.ylabel('Valores')
plt.show()

# %%
import seaborn as sns

sns.regplot(data=am, x='populacao_estimada', y='area_territorial')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'populacao_estimada'
#
# ...
